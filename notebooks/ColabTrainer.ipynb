# %%
#extract training data
#!/content/drive/MyDrive/fewshot_data.zip
#!unzip /content/drive/MyDrive/fewshot_data.zip -d /content/drive/MyDrive/

#save code
#%cd fewshot-segmentation/source_code/
#!mkdir /content/drive/MyDrive/sc
#!cp -fr ./* /content/drive/MyDrive/sc/

# %%
#!git clone --recursive https://github.com/OlegJakushkin/fewshot-segmentation 
# %cd /content/drive/MyDrive/sc/
# !mkdir /content/fewshot_data/
# !cp /content/drive/MyDrive/fewshot_data.zip /content/
# !rm -rf /content/fewshot_data/
# !unzip /content/fewshot_data.zip -d /content/
# Out:
# Выходные данные были обрезаны до нескольких последних строк (5000).
#   inflating: /content/fewshot_data/fewshot_data/sea_urchin/9.png
#    creating: /content/fewshot_data/fewshot_data/sewing_machine/
#   inflating: /content/fewshot_data/fewshot_data/sewing_machine/1.jpg
#   inflating: /content/fewshot_data/fewshot_data/sewing_machine/1.png
#   inflating: /content/fewshot_data/fewshot_data/sewing_machine/10.jpg
#   inflating: /content/fewshot_data/fewshot_data/sewing_machine/10.png
#   inflating: /content/fewshot_data/fewshot_data/sewing_machine/2.jpg
#   inflating: /content/fewshot_data/fewshot_data/sewing_machine/2.png
#   inflating: /content/fewshot_data/fewshot_data/sewing_machine/3.jpg
#   inflating: /content/fewshot_data/fewshot_data/sewing_machine/3.png
#   inflating: /content/fewshot_data/fewshot_data/sewing_machine/4.jpg
#   inflating: /content/fewshot_data/fewshot_data/sewing_machine/4.png
#   inflating: /content/fewshot_data/fewshot_data/sewing_machine/5.jpg
# ...

# %%
# !pip uninstall -yq tf-nightly-gpu  tensorflow keras tensorflow-gpu keras-preprocessing keras-applications 
# !pip install tensorflow-gpu==1.13.1
# !pip install numpy keras==2.3 keras-applications==1.0.6 keras-preprocessing==1.0.5
# Out:
# WARNING: Skipping tf-nightly-gpu as it is not installed.
# WARNING: Skipping tensorflow-gpu as it is not installed.
# WARNING: Skipping keras-applications as it is not installed.
# ...
#      |████████████████████████████████| 345.2MB 44kB/s
# ...
#      |████████████████████████████████| 3.2MB 53.0MB/s
# ...
#      |████████████████████████████████| 368kB 62.4MB/s
# ...
#      |████████████████████████████████| 51kB 7.8MB/s
# ...
#      |████████████████████████████████| 51kB 8.3MB/s
# ...
#   Found existing installation: tensorboard 2.3.0
#     Uninstalling tensorboard-2.3.0:
#       Successfully uninstalled tensorboard-2.3.0
#   Found existing installation: tensorflow-estimator 2.3.0
#     Uninstalling tensorflow-estimator-2.3.0:
#       Successfully uninstalled tensorflow-estimator-2.3.0
# ...
#      |████████████████████████████████| 378kB 4.2MB/s
# ...
#      |████████████████████████████████| 51kB 7.7MB/s
# ...
# ERROR: fancyimpute 0.4.3 requires tensorflow, which is not installed.
# ...

# %%
# !nvidia-smi
# !python ./Train_DOGLSTM.py -ks=5   -its=1000
# Out:
# Sun Dec  6 13:52:48 2020
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 455.45.01    Driver Version: 418.67       CUDA Version: 10.1     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla P100-PCIE...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   37C    P0    26W / 250W |      0MiB / 16280MiB |      0%      Default |
# |                               |                      |                 ERR! |
# +-------------------------------+----------------------+----------------------+
#
# ...
